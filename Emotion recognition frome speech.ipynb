# %%
#pip install librosa

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
# Let's simulate MFCC features like from real audio
np.random.seed(42)
num_samples = 1000
num_features = 40  # Common number of MFCCs

# Random MFCC features
X = np.random.rand(num_samples, num_features)

# 3 emotion classes
emotions = ['happy', 'sad', 'angry']
y = np.random.choice(emotions, size=num_samples)

# Convert emotions to numeric labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Show a few examples
print("Emotions encoded:", list(zip(y[:5], y_encoded[:5])))
# Out:
# Emotions encoded: [(np.str_('happy'), np.int64(1)), (np.str_('happy'), np.int64(1)), (np.str_('angry'), np.int64(0)), (np.str_('happy'), np.int64(1)), (np.str_('angry'), np.int64(0))]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42
)

# %%
model = Sequential([
    Dense(256, activation='relu', input_shape=(num_features,)),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(3, activation='softmax')  # 3 emotion classes
])

model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=20, batch_size=32,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.3511 - loss: 1.1308 - val_accuracy: 0.3200 - val_loss: 1.1224
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3740 - loss: 1.0969 - val_accuracy: 0.3250 - val_loss: 1.1162
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3678 - loss: 1.0907 - val_accuracy: 0.3250 - val_loss: 1.1109
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4104 - loss: 1.0812 - val_accuracy: 0.3350 - val_loss: 1.1151
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4199 - loss: 1.0685 - val_accuracy: 0.3100 - val_loss: 1.1397
# Epoch 6/20
# ...

# %%
model = Sequential([
    Dense(256, activation='relu', input_shape=(num_features,)),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(3, activation='softmax')  # 3 emotion classes
])

model.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=20, batch_size=32,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.3240 - loss: 1.1129 - val_accuracy: 0.3150 - val_loss: 1.1105
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3840 - loss: 1.0921 - val_accuracy: 0.3200 - val_loss: 1.1002
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3672 - loss: 1.0890 - val_accuracy: 0.2900 - val_loss: 1.1302
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3808 - loss: 1.0817 - val_accuracy: 0.3000 - val_loss: 1.1287
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3957 - loss: 1.0728 - val_accuracy: 0.3400 - val_loss: 1.1370
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3899 - loss: 1.0760 - val_accuracy: 0.2700 - val_loss: 1.1440
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4662 - loss: 1.0418 - val_accuracy: 0.2850 - val_loss: 1.1212
# Epoch 8/20
# ...

# %%
# Plot training history
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Predictions
y_pred = np.argmax(model.predict(X_test), axis=1)

# Evaluation metrics
print("Classification Report:\n", classification_report(y_test, y_pred, target_names=emotions))

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues",
            xticklabels=emotions, yticklabels=emotions)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#        happy       0.31      0.53      0.39        64
#          sad       0.39      0.17      0.24        82
#        angry       0.28      0.28      0.28        54
#
#     accuracy                           0.32       200
#    macro avg       0.33      0.33      0.30       200
# weighted avg       0.33      0.32      0.30       200
